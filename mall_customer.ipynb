# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings 
warnings.filterwarnings('ignore')

# %%
data= pd.read_csv('Mall_Customers.csv')
data
# Out:
#      CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]

# %%
data.describe()
# Out:
#        CustomerID         Age  Annual Income (k$)  Spending Score (1-100)
# count  200.000000  200.000000          200.000000              200.000000
# mean   100.500000   38.850000           60.560000               50.200000
# std     57.879185   13.969007           26.264721               25.823522
# min      1.000000   18.000000           15.000000                1.000000
# 25%     50.750000   28.750000           41.500000               34.750000
# 50%    100.500000   36.000000           61.500000               50.000000
# 75%    150.250000   49.000000           78.000000               73.000000
# max    200.000000   70.000000          137.000000               99.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   CustomerID              200 non-null    int64
#  1   Gender                  200 non-null    object
#  2   Age                     200 non-null    int64
#  3   Annual Income (k$)      200 non-null    int64
#  4   Spending Score (1-100)  200 non-null    int64
# dtypes: int64(4), object(1)
# memory usage: 7.9+ KB

# %%
data.isnull().sum()
# Out:
# CustomerID                0
# Gender                    0
# Age                       0
# Annual Income (k$)        0
# Spending Score (1-100)    0
# dtype: int64

# %%
# Data Visuliation and EDA

# %%
data.columns
# Out:
# Index(['CustomerID', 'Gender', 'Age', 'Annual Income (k$)',
#        'Spending Score (1-100)'],
#       dtype='object')

# %%
plt.figure(figsize=(15,7))

sns.displot(data['Age'])
plt.title('Distribution of Age')
plt.xlabel('Age')
plt.ylabel('count')
plt.show()


sns.displot(data['Annual Income (k$)'])
plt.title('Distribution of Income')
plt.xlabel('Annual Income')
plt.ylabel('count')
plt.show()


sns.displot(data['Spending Score (1-100)'])
plt.title('Distribution of Spending Score')
plt.xlabel('Spending Score')
plt.ylabel('count')
plt.show()

# %%
df = data.groupby('Gender').size()
df.plot(kind= 'pie',subplots= True,
       colors= ['lightblue','limegreen'],
       explode= [0,0.001],
       labels= ['Female','Male'],
       autopct ='%.f2%%')
plt.title('Gender Distribution')
plt.ylabel('Gender')
plt.show()

# %%
data.hist(figsize=(14,8))
plt.show()

# %%
sns.pairplot(data)
plt.show()

# %%
sns.pairplot(data, vars=['Age','Annual Income (k$)','Spending Score (1-100)'],hue='Gender')

# %%
plt.figure(figsize=(16,8))
sns.countplot(data['Age'])
plt.title(['Distributionof Age'])
# Out:
# Text(0.5, 1.0, "['Distributionof Age']")

# %%
plt.figure(figsize=(16,8))
sns.countplot(data['Annual Income (k$)'])
plt.title(['Distributionof Annual Income (k$)'])
# Out:
# Text(0.5, 1.0, "['Distributionof Annual Income (k$)']")

# %%
plt.figure(figsize=(16,8))
sns.countplot(data['Spending Score (1-100)'])
plt.title(['Distributionof Spending Score (1-100)'])
# Out:
# Text(0.5, 1.0, "['Distributionof Spending Score (1-100)']")

# %%
# Define the target column
target_col = 'Spending Score (1-100)'

# Plot 1: Distribution of Spending Score
plt.figure(figsize=(10, 6))
sns.histplot(data[target_col], kde=True, bins=10, color='skyblue')
plt.title(f'Distribution of {target_col}')
plt.xlabel(target_col)
plt.ylabel('Frequency')
plt.show()

# Plot 2: Relationship between Age and Spending Score
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Age', y=target_col, data=data, color='orange')
plt.title(f'Relationship between Age and {target_col}')
plt.xlabel('Age')
plt.ylabel(target_col)
plt.show()

# Plot 3: Boxplot for Spending Score based on Gender
plt.figure(figsize=(10, 6))
sns.boxplot(x='Gender', y=target_col, data=data, palette='Set2')
plt.title(f'{target_col} by Gender')
plt.xlabel('Gender')
plt.ylabel(target_col)
plt.show()

# %%
data.columns
# Out:
# Index(['CustomerID', 'Gender', 'Age', 'Annual Income (k$)',
#        'Spending Score (1-100)'],
#       dtype='object')

# %%
x=data.iloc[:,[3,4]].values

# %%
x
# Out:
# array([[ 15,  39],
#        [ 15,  81],
#        [ 16,   6],
#        [ 16,  77],
#        [ 17,  40],
#        [ 17,  76],
#        [ 18,   6],
#        [ 18,  94],
#        [ 19,   3],
#        [ 19,  72],
#        [ 19,  14],
#        [ 19,  99],
#        [ 20,  15],
#        [ 20,  77],
#        [ 20,  13],
#        [ 20,  79],
#        [ 21,  35],
#        [ 21,  66],
#        [ 23,  29],
#        [ 23,  98],
#        [ 24,  35],
#        [ 24,  73],
#        [ 25,   5],
#        [ 25,  73],
#        [ 28,  14],
#        [ 28,  82],
#        [ 28,  32],
#        [ 28,  61],
#        [ 29,  31],
#        [ 29,  87],
#        [ 30,   4],
#        [ 30,  73],
#        [ 33,   4],
#        [ 33,  92],
#        [ 33,  14],
#        [ 33,  81],
#        [ 34,  17],
#        [ 34,  73],
#        [ 37,  26],
#        [ 37,  75],
#        [ 38,  35],
#        [ 38,  92],
#        [ 39,  36],
#        [ 39,  61],
#        [ 39,  28],
#        [ 39,  65],
#        [ 40,  55],
# ...

# %%
from sklearn.cluster import KMeans

# %%
k =[]
for i in range(1,11):
    kmeans = KMeans(n_clusters=i,init = 'k-means++',random_state =0)
    kmeans.fit(x)
    k.append(kmeans.inertia_)
    
plt.plot(range(1,11),k,marker='o')    
plt.title('Elbow method')
plt.xlabel('Number of clusters')
plt.ylabel('Inertia')
plt.show()

# %%
model = KMeans(n_clusters=5,init = 'k-means++',random_state =0)
kmeans=model.fit_predict(x)

# %%
cluster_centers = model.cluster_centers_
print("Cluster Centers: \n", cluster_centers)

# Visualize the clusters (for 2D data)

plt.scatter(x[:, 0], x[:, 1], c=kmeans, cmap='viridis')
plt.scatter(cluster_centers[:, 0], cluster_centers[:, 1], c='Black', marker='o', s=200, label='Centroids')
plt.title("KMeans Clustering")
plt.legend()
plt.show()

#  Evaluate clustering quality with silhouette score
from sklearn.metrics import silhouette_score
silhouette_avg = silhouette_score(x, kmeans)
print("Silhouette Score:", silhouette_avg)
# Out:
# Cluster Centers:
#  [[ 82.38888889  90.44444444]
#  [ 28.18181818  33.27272727]
#  [ 63.95238095  46.21428571]
#  [ 84.46428571  15.32142857]
#  [ 25.0952381   80.04761905]
#  [ 77.78571429  73.28571429]
#  [ 47.86046512  51.97674419]
#  [ 24.58333333   9.58333333]
#  [114.71428571  78.42857143]
#  [124.          17.5       ]]
# Silhouette Score: 0.553931997444648
